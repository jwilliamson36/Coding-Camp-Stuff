# %% [markdown]
# # **How did Superman and the Flash differ?**
#
# ### Grodd is currently trying to destroy the city.  When the call came in Superman was flying over exit 250 (measured in km) at 455 m/s and just continued at the same speed onto the scene of the attack while The Flash was sitting and eating lunch and then took off straight toward the scene, accelerating at 3.78 m/s^2.  Your task is to use the following information and analyze the motion of both superheros as they travel to the scene.
#
#
# * The Hall of Justice is located right off of exit 32 (measured in km)
# * The distruction is taking place at exit 141 (measured in km)
# * Both men left at 11:00 am

# %%
# These are some software packages we'll use to allow us to analyze this problem (Remember to run after each code section is complete)
import pandas as pd
import numpy as np
from math import cos,sin,pi
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#Defining Lists and Equations used for Superman
xi = 250000    #the initial position of Superman
xf = 141000   #the final position of Superman
vs = -455      #the velocity of Superman
sa = 0        #the acceleration of Superman
tdelta = 10   #the periods of time we will calculate data
t = 0         #the initial time
S = xi    #the position of Superman at any moment in time
Sv = vs   #the velocity of Superman at any moment in time
tlist = [] #create a list for the time values
Slist = [] #create a list for the position values
Svlist = [] #create a list for the velocity values
tlist.append(t)
Slist.append(S)
Svlist.append(Sv)



while S >= 141000: #stop the calculations after Superman reaches Grodd
    S = .5*sa*tdelta*tdelta + vs*tdelta + S #calculating the position at any moment in time
    Slist.append(S)

    Sv = sa*tdelta + Sv #calculating the velocity at any moment in time
    Svlist.append(Sv)

    t = t + tdelta #calculating the time at each interval
    tlist.append(t)

Sdata = pd.DataFrame({"t": tlist, "S": Slist, "Sv": Svlist})
Sdata.head(5) # only see first five rows of data
# Out:
#     t         S   Sv
# 0   0  250000.0 -455
# 1  10  245450.0 -455
# 2  20  240900.0 -455
# 3  30  236350.0 -455
# 4  40  231800.0 -455

# %%
#Defining Lists and Equations used for the Flash
Fxi = 32000
Fxf = 141000
Fvi = 0
Fa = 3.78
tdelta = 30
t = 0
Fv = Fvi   #the velocity of the Flash
F = Fxi    #the position of the Flash
tlist = []
Flist = []
Fvlist = []
tlist.append(t)
Flist.append(F)
Fvlist.append(Fv)


while F <= 141000:

    F = .5*Fa*tdelta*tdelta + Fv*tdelta + F
    Flist.append(F)

    Fv = Fa*tdelta + Fv
    Fvlist.append (Fv)
    t = t + tdelta
    tlist.append(t)

Fdata = pd.DataFrame({"t": tlist, "F": Flist, "Fv": Fvlist})
Fdata.head (5)
# Out:
#      t        F     Fv
# 0    0  32000.0    0.0
# 1   30  33701.0  113.4
# 2   60  38804.0  226.8
# 3   90  47309.0  340.2
# 4  120  59216.0  453.6

# %% [markdown]
# 1.   Does your data make sense based upon the given values.  Explain with evidence why or why not.
# 2.   Which superhero was travling the fastest?  Give evidence to support your answer.
# 3.   Which superhero traveled the furthest?  Give evidence to support your answer.

# %%
#What does the data for Superman and the Flash look like graphically?  Create a position time graph for each one and then combine them into one

plt.plot(Sdata['t'],Sdata['S'], linestyle='--', marker='o', color='b', markersize=20)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.title('Superman Position vs Time')
plt.grid(True)
plt.show()

# %%
#What does the graphical representation of the Flash look like?
plt.plot(Fdata['t'],Fdata['F'], linestyle='--', marker='o', color='r', markersize=20)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.title('The Flash Position vs Time')
plt.grid(True)
plt.show()

# %%
plt.plot(Sdata['t'],Sdata['S'],linestyle='--', marker='o', color='b', markersize=20)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.title('Position vs Time')

plt.plot(Fdata['t'],Fdata['F'],linestyle='--', marker='o', color='r', markersize=20)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.title('Position vs Time')
plt.grid(True)
plt.show()

# %% [markdown]
# # VELOCITY vs TIME GRAPHS
#
#
# 1.   Briefly describe what the graph tells you about the movement of Superman, using evidence from the graph.
# 2.   Briefly describe what the graph tells you about the moment of the Flash, using evidence from the graph.
# 3.   Briefly describe any similarities between Superman and the Flash that is obvious from the graph.
# 4.   Briefly describe how the graphs differ and what this means about the movement of each superhero.

# %%
#Compare the velocity vs time graphs

plt.plot(Sdata['t'],Sdata['Sv'], linestyle='--', marker='o', color='b', markersize=20)
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.title('Superman Velocity vs Time')
plt.grid(True)
plt.show()

plt.plot(Fdata['t'],Fdata['Fv'], linestyle='--', marker='o', color='r', markersize=20)
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.title('The Flash Velocity vs Time')
plt.grid(True)
plt.show()


plt.plot(Sdata['t'],Sdata['Sv'],linestyle='--', marker='o', color='b', markersize=20)
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.title('Velocity vs Time')

plt.plot(Fdata['t'],Fdata['Fv'],linestyle='--', marker='o', color='r', markersize=20)
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.title('Velocity vs Time')
plt.grid(True)
plt.show()

# %% [markdown]
# # VELOCITY vs TIME GRAPHS
#
#
# 1.   Briefly describe what the graph tells you about the movement of Superman, using evidence from the graph.
# 2.   Briefly describe what the graph tells you about the moment of the Flash, using evidence from the graph.
# 3.   Briefly describe any similarities between Superman and the Flash that is obvious from the graph.
# 4.   Briefly describe how the graphs differ and what this means about the movement of each superhero.
# 5.   Is there ever a moment in time where the two superheros are both moving at the same speed?  Velocity?  Explain.

# %% [markdown]
# # FINAL ANALYSIS
#
# 1. Describe at least three different types of information that can be determined from a position vs. time graph about the motion of an object?
# 2. What is not possible/or easy to determine from a postion vs. time graph?
# 3. Describe at least three different types of information that can be determined from a velocity vs. time graph about the motion of an object?
# 4. What cannot be determined solely from a velocity vs. time graph?
#
#
#
# 5. In a short complete sentence, describe the motion of the object in the graph below.
#
# ![Position Time Graph](http://www.physicsclassroom.com/Class/1DKin/U1L3b2.gif)
#
#
#
# 6. In a short complete sentence, describe the motion of the object between 4s and 9s in the graph below.
#
#
#   ![Velocity Time Graph](https://www.webassign.net/serpse9/2-p-062.gif)
#
#
# 7. Pick two letters and clearly describe in a complete sendence  two differences between the two objects shown in the graph below.
#
#
#    ![Velocity Time Graph](http://dev.physicslab.org/img/99d8b8ec-5428-4259-ab6a-99c47957c1d5.gif)
