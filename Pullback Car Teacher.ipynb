# %% [markdown]
# #Pullback Car Lab
# Think back to your initial lab using the buggy
# - Describe how the motion of the pullback car is different from the buggy.
# - What difference will this do to your position vs time graph?
#
# Using the spark timer collect a run of position and time data and record in Google Sheets then save the file as a csv file onto the destop of the laptop with a unique identifiable name for your group.

# %%
# These are some software packages we'll use to allow us to analyze this problem (Remember to run after each code section is complete)
import pandas as pd
import numpy as np
from math import cos,sin,pi
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from google.colab import files #this will allow you to access and upload your file from the computer.
uploaded = files.upload()  #let it upload 100% before proceding
# Out:
#      <input type="file" id="files-d16a0356-428c-4661-9cce-fd3ef8785568" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d16a0356-428c-4661-9cce-fd3ef8785568">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
#be sure to type in the exact file name
dataset = pd.read_csv(io.BytesIO(uploaded['pullbackcar.csv']))
# Dataset is now stored in a Pandas Dataframe
dataset.head(5) #the number in parenthesis tells you how many lines of data will be shown, no number will show all data
# Out:
#      Time  Position
# 0  0.0000       0.0
# 1  0.0167       0.4
# 2  0.0334       0.5
# 3  0.0501       0.6
# 4  0.0668       0.8

# %%
#create a position vs time scatter plot graph for the data with proper labels
x=dataset.Time
y=dataset.Position
plt.scatter(x,y, s=20, alpha=1, edgecolors='blue') # defines the graph as a scatterplot with x and y
plt.title('Position vs Time')
plt.xlabel("Time")
plt.ylabel("Position")
plt.show()

# %% [markdown]
# #What Now?
# - Was your predition about the change to the graph correct?
# - What can you do to straighten out the line and have a linear relationship?

# %%
#Add another column of data so that you can create a linear graph
dataset['TimeSquared'] = dataset['Time']**2 #add to the data set with set name and = what calculation
dataset.head(5)
# Out:
#      Time  Position  TimeSquared
# 0  0.0000       0.0     0.000000
# 1  0.0167       0.4     0.000279
# 2  0.0334       0.5     0.001116
# 3  0.0501       0.6     0.002510
# 4  0.0668       0.8     0.004462

# %%
# create a new graph that is properly labeled.
x=dataset.TimeSquared
y=dataset.Position
plt.scatter(x,y, s=20, alpha=1, edgecolors='blue') # defines the graph as a scatterplot with x and y
plt.title('Position vs Time^2')
plt.xlabel("Time^2")
plt.ylabel("Position")

# this will draw a best fit line based upon a slope and y-intercept
m, b = np.polyfit(x, y, deg=1)
plt.axline(xy1=(0, b), slope=m, label=f'x = {m:.1f}t2 {b:+.1f}', color='r') #change your labels to reflect what is actually on the graph

plt.legend() #this will show the equation of the best fit line

plt.show()

# %% [markdown]
# #Conclusions:
# 1. Analyze the y-intercept, can you round it to zero or not and why?
# 2. What would be the units of the slope?
# 3. What concept do you think that the units are connected to?
